# %% [markdown]
# <font size=5>作業1:<font size=3>
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# https://www.kaggle.com/c/LANL-Earthquake-Prediction/overview
#
# 1. 你選的這組資料為何重要
#
#    ●目前的科學研究還無法準確的判斷何時地震會產生，因此此實驗團隊透過在實驗室模擬地震發生來預測地震發生的地點、
#     時間及其規模，若能成功預測，在重大地震來臨前可以提早挽救無數生命及基礎建設。
#
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
#    ●資料由一個模擬地震的實驗裝置來(The data are from an experiment conducted on rock in a double direct
#     shear geometry subjected to bi-axial loading)，由Los Alamos National Laboratory提供
#
#
# 3. 蒐集而來的資料型態為何
#
#    ●CSV
#
#
# 4. 這組資料想解決的問題如何評估
#
#    ●從即時的seismic data預測實驗室地震發生前的剩餘時間
#    ●下一次實驗地震前的剩餘預測時間與實際剩餘時間之間的平均絕對誤差來評估(Submissions are evaluated using
#     the mean absolute error between the predicted time remaining before the next lab earthquake and
#     the act remaining time.)
#
#
#
# <font size=5>作業2：<font size=3>
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
#    ●增加白天的載客數量以提升業績而不著墨夜間運量
#    ●我的假設:自由載客的經營模式很單一，要讓顧客願意回流及搭乘，服務的建立、多角化經營以及便利性是最重要的，例
#     如，除了一般的到指定地點載送及手機叫車外，亦可結合外送服務，顧客在家就能透過車隊進行外送食物或是商品的服
#     務，並推出促銷及集點活動，為下次搭乘提供回饋金。
#
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
#    ●資料由市場調查而來，可以透過填寫問卷的方式
#    ●可能影響資料的因素有天氣、例假日、客源年紀層。
#
#
# 3. 蒐集而來的資料型態為何
#
#    ●為文字資料
#
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
#    ●對每次載客進行資料統計，以統計出每個因素對每項服務的趨勢情況。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 13.683

# %%
def Mean_Square_Error(y, yp):
    mse = MSE = sum(np.square(y - yp)) / len(y)
    """
    np.square為將數值平方的函數
    """
    return mse

MSE = Mean_Square_Error(y, y_hat)
print("The Mean Square error is %.3f" % (MSE))
# Out:
# The Mean Square error is 280.010
